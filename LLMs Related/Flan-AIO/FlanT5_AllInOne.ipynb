# %% [markdown]
# # Installing dependencies

# %%
! pip install datasets transformers accelerate peft
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.2 MB/s eta 0:00:00
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 33.8 MB/s eta 0:00:00
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 17.4 MB/s eta 0:00:00
# Collecting peft
#   Downloading peft-0.5.0-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 21.0 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.6)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 31.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 10.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.0.1+cu118)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Collecting huggingface-hub<1.0.0,>=0.14.0 (from datasets)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.10.0->accelerate) (17.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: xxhash, safetensors, dill, multiprocess, huggingface-hub, tokenizers, transformers, datasets, accelerate, peft
# Successfully installed accelerate-0.23.0 datasets-2.14.5 dill-0.3.7 huggingface-hub-0.17.3 multiprocess-0.70.15 peft-0.5.0 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0 xxhash-3.4.1

# %% [markdown]
# ## Datasets
#
# - Text Classification - dair-ai/emotion
# - Question Answering - mlqa.hi.en
# - Question Generation - squad
# - Paraphrasing - paws
# - Summarization - samsum
# - Text Generation - sadFaceEmoji/english-poems
# - Semantic Similarity - paws

# %% [markdown]
# # Download and Process Data

# %%
from datasets import load_dataset, Dataset
import pandas as pd

# %% [markdown]
# # Text Classification

# %%
# dair-ai/emotion - Text Classification

text_classification_data = load_dataset("dair-ai/emotion", "split", split="test")
text_classification_data
# Out:
# Downloading builder script:   0%|          | 0.00/3.97k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/3.28k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.78k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/592k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/74.9k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/16000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 2000
# })

# %%
text_classification_df = text_classification_data.to_pandas()
text_classification_df
# Out:
#                                                    text  label
# 0     im feeling rather rotten so im not very ambiti...      0
# 1             im updating my blog because i feel shitty      0
# 2     i never make her separate from me because i do...      0
# 3     i left with my bouquet of red and yellow tulip...      1
# 4       i was feeling a little vain when i did this one      0
# ...                                                 ...    ...
# 1995  i just keep feeling like someone is being unki...      3
# 1996  im feeling a little cranky negative after this...      3
# 1997  i feel that i am useful to my people and that ...      1
# 1998  im feeling more comfortable with derby i feel ...      1
# 1999  i feel all weird when i have to meet w people ...      4
#
# [2000 rows x 2 columns]

# %%
map_emotions = {
    0: "sadness",
    1: "joy",
    2: "love",
    3: "anger",
    4: "fear",
    5: "surprise"
}

text_classification_df["target"] = text_classification_df["label"].apply(lambda x: map_emotions[x])
text_classification_df["source"] = text_classification_df["text"].apply(lambda x: "text-classification-emotion: " + x)

text_classification_df = text_classification_df[["source", "target"]]
text_classification_df
# Out:
#                                                  source   target
# 0     text-classification-emotion: im feeling rather...  sadness
# 1     text-classification-emotion: im updating my bl...  sadness
# 2     text-classification-emotion: i never make her ...  sadness
# 3     text-classification-emotion: i left with my bo...      joy
# 4     text-classification-emotion: i was feeling a l...  sadness
# ...                                                 ...      ...
# 1995  text-classification-emotion: i just keep feeli...    anger
# 1996  text-classification-emotion: im feeling a litt...    anger
# 1997  text-classification-emotion: i feel that i am ...      joy
# 1998  text-classification-emotion: im feeling more c...      joy
# 1999  text-classification-emotion: i feel all weird ...     fear
#
# [2000 rows x 2 columns]

# %%
text_classification_df = text_classification_df.sample(500)
text_classification_df
# Out:
#                                                  source   target
# 1488  text-classification-emotion: i managed however...     love
# 726   text-classification-emotion: i lift different ...     fear
# 325   text-classification-emotion: i bought it at ur...  sadness
# 1961  text-classification-emotion: i remember wantin...     love
# 998   text-classification-emotion: i feel like he mo...      joy
# ...                                                 ...      ...
# 1250  text-classification-emotion: i did feel for hi...  sadness
# 236   text-classification-emotion: i feel like some ...  sadness
# 1027  text-classification-emotion: i think were on a...     fear
# 1241  text-classification-emotion: i could maybe get...  sadness
# 1126  text-classification-emotion: i come in contact...      joy
#
# [500 rows x 2 columns]

# %% [markdown]
# # Question Answering

# %%
data = load_dataset("mlqa", "mlqa.hi.en", split="validation")
# Out:
# Downloading builder script:   0%|          | 0.00/8.44k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/114k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/34.9k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/75.7M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4918 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/507 [00:00<?, ? examples/s]

# %%
qa_df = data.to_pandas()
qa_df
# Out:
#                                                context  \
# 0    पैरेनकाइमा कोशिकाएं वे जीवित कोशिकाएं हैं जो स...
# 1    पैरेनकाइमा कोशिकाएं वे जीवित कोशिकाएं हैं जो स...
# 2    जाइलेम कोशिकाएं कोशिका भित्तियों की लिग्निकृत ...
# 3    फ्लोएम उच्चतर पौधों में आहार का संवहन करने वाल...
# 4    सभी हवाई अवयवों की बाह्यत्वचा, जड़ों को छोड़कर...
# ..                                                 ...
# 502  स्पार्टाकस नाम वैसे काले सागर क्षेत्र में साक्...
# 503  इस समय तक पोम्पे की टुकड़ी स्पेन लौट चुकी थी औ...
# 504  आर्गन-39, 269 वर्ष की एक आधा जीवन के साथ, आवेद...
# 505  जॉनस्टन का जन्म व बचपन ओंटारियो में बीता। वहाँ...
# 506  क्रिस एंजल, ए ऐंड ई नेटवर्क (A&E Network) के क...
#
#                                               question  \
# 0    What is the name of a type of string that cons...
# 1    What are made up almost entirely of parenchyma...
# 2                   What kind of plants possess xylem?
# 3                                 What is the leptome?
# 4                         Epidermal cells can do what?
# ..                                                 ...
# 502                                        which King?
# 503                What happened to captured soldiers?
# 504                 What is the half-life of Argon 39?
# 505  What role  in government did Stephen Harper have?
# 506                 What hotel was season 3 filmed at?
#
#                                                answers  \
# 0    {'answer_start': [2267], 'text': ['कोलेन्काइमा']}
# 1        {'answer_start': [158], 'text': ['पत्तियां']}
# 2    {'answer_start': [292], 'text': ['ट्रेकियोफाइट...
# 3    {'answer_start': [969], 'text': ['समान कार्य क...
# 4    {'answer_start': [433], 'text': ['क्यटिन का सं...
# ..                                                 ...
# 502  {'answer_start': [89], 'text': ['थ्रेसियन राजव...
# 503  {'answer_start': [1094], 'text': ['क्रूस पर चढ...
# 504       {'answer_start': [10], 'text': ['269 वर्ष']}
# 505  {'answer_start': [669], 'text': ['प्रधानमंत्री']}
# 506         {'answer_start': [190], 'text': ['लक्सर']}
#
#                                            id
# 0    60ee75c50c8472be7cce1a24ee2cd7409ee4dd52
# 1    561971f7978f678c3d1ba2a946036cdc131c4d49
# 2    18a5c05701b7359fcd32a379b2ac4a9a5d7544de
# 3    694ce8b90f6854bcd6c3a505767df90f8b659d06
# 4    25be1db3766bfbb5f64b3a8f4bf4af57470eb651
# ..                                        ...
# 502  c555e59e9cf74869aaf94cbeaf932cd1fd89e55e
# 503  1f79f28190b12342fc7a39cea0202d33af7488c9
# 504  cc81fb916f547d7d51730e0f726891179b361ebd
# 505  244b552d2f8e850eb0b88d4c7440c575639fa911
# 506  4716c0c31202186e963a12a50143d48978f8a0a2
#
# [507 rows x 4 columns]

# %%
qa_df["source"] = qa_df[["context", "question"]].apply(lambda x: "context-question-answering: context: " + x["context"] + " question: " + x["question"], axis=1)
qa_df["target"] = qa_df["answers"].apply(lambda x: x["text"][0])

qa_df = qa_df[["source", "target"]]
qa_df
# Out:
#                                                 source  \
# 0    context-question-answering: context: पैरेनकाइम...
# 1    context-question-answering: context: पैरेनकाइम...
# 2    context-question-answering: context: जाइलेम को...
# 3    context-question-answering: context: फ्लोएम उच...
# 4    context-question-answering: context: सभी हवाई ...
# ..                                                 ...
# 502  context-question-answering: context: स्पार्टाक...
# 503  context-question-answering: context: इस समय तक...
# 504  context-question-answering: context: आर्गन-39,...
# 505  context-question-answering: context: जॉनस्टन क...
# 506  context-question-answering: context: क्रिस एंज...
#
#                                    target
# 0                             कोलेन्काइमा
# 1                                पत्तियां
# 2                          ट्रेकियोफाइटों
# 3    समान कार्य करने वाला एक अधिक सरल ऊतक
# 4                      क्यटिन का संश्लेषण
# ..                                    ...
# 502               थ्रेसियन राजवंश के राजा
# 503               क्रूस पर चढ़ा दिया गया।
# 504                              269 वर्ष
# 505                          प्रधानमंत्री
# 506                                 लक्सर
#
# [507 rows x 2 columns]

# %% [markdown]
# # Question Generation

# %%
data = load_dataset("squad_v2", split="validation")
qgen_df = data.to_pandas()
qgen_df = qgen_df.sample(500)
# Out:
# Downloading builder script:   0%|          | 0.00/5.28k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/8.02k [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/9.55M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/801k [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/130319 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/11873 [00:00<?, ? examples/s]

# %%
qgen_df
# Out:
#                              id                  title  \
# 4592   5a669b3df038b7001ab0c04e       Packet_switching
# 11385  5733fd66d058e614000b6737  French_and_Indian_War
# 8998   5729a3716aef05140015506d           Prime_number
# 3728   572646655951b619008f6ec0             Ctenophora
# 1952   5ad3e8f6604f3c001a3ff66b           Steam_engine
# ...                         ...                    ...
# 9178   5ad27abcd7d075001a42962d                  Rhine
# 3745   5a835778e60761001a2eb5dd             Ctenophora
# 5229   5a6cb7ce4eec6b001a80a639               Pharmacy
# 4012   5a7b070121c2de001afe9cee     Fresno,_California
# 4784   5a2ecfb1a83784001a7d24c8            Black_Death
#
#                                                  context  \
# 4592   Internet2 is a not-for-profit United States co...
# 11385  The new British command was not in place until...
# 8998   Prime numbers have influenced many artists and...
# 3728   Ctenophores form an animal phylum that is more...
# 1952   The most useful instrument for analyzing the p...
# ...                                                  ...
# 9178   The Rhine is the longest river in Germany. It ...
# 3745   Like sponges and cnidarians, ctenophores have ...
# 5229   A Pharmacy Technician in the UK is considered ...
# 4012   In September 1958, Bank of America launched a ...
# 4784   A variety of alternatives to the Y. pestis hav...
#
#                                                 question  \
# 4592   What was the first Internet2 Network created w...
# 11385  Where did Moncalm slip away to attack, left la...
# 8998   In which etude of Neumes rythmiques do the pri...
# 3728   What do ctenophores have that no other animals...
# 1952   What instrument is used to examine diagram per...
# ...                                                  ...
# 9178   How much water does the Rhine discharge at the...
# 3745   How many layers of cells with a sandwiched jel...
# 5229   With what body must a pharmacy not be allowed ...
# 4012   The BankAmericard could be used across many me...
# 4784   In what year was Scott and Duncan's research p...
#
#                                                  answers
# 4592                    {'text': [], 'answer_start': []}
# 11385  {'text': ['Oswego', 'Oswego', 'Oswego', 'Osweg...
# 8998   {'text': ['the third étude', 'third', 'third',...
# 3728   {'text': ['colloblasts', 'colloblasts', 'collo...
# 1952                    {'text': [], 'answer_start': []}
# ...                                                  ...
# 9178                    {'text': [], 'answer_start': []}
# 3745                    {'text': [], 'answer_start': []}
# 5229                    {'text': [], 'answer_start': []}
# 4012                    {'text': [], 'answer_start': []}
# 4784                    {'text': [], 'answer_start': []}
#
# [500 rows x 5 columns]

# %%
qgen_df["source"] = qgen_df["context"].apply(lambda x: "context-question-generation: " + x)
qgen_df["target"] = qgen_df["question"]

# %%
qgen_df = qgen_df[["source", "target"]]
qgen_df
# Out:
#                                                   source  \
# 4592   context-question-generation: Internet2 is a no...
# 11385  context-question-generation: The new British c...
# 8998   context-question-generation: Prime numbers hav...
# 3728   context-question-generation: Ctenophores form ...
# 1952   context-question-generation: The most useful i...
# ...                                                  ...
# 9178   context-question-generation: The Rhine is the ...
# 3745   context-question-generation: Like sponges and ...
# 5229   context-question-generation: A Pharmacy Techni...
# 4012   context-question-generation: In September 1958...
# 4784   context-question-generation: A variety of alte...
#
#                                                   target
# 4592   What was the first Internet2 Network created w...
# 11385  Where did Moncalm slip away to attack, left la...
# 8998   In which etude of Neumes rythmiques do the pri...
# 3728   What do ctenophores have that no other animals...
# 1952   What instrument is used to examine diagram per...
# ...                                                  ...
# 9178   How much water does the Rhine discharge at the...
# 3745   How many layers of cells with a sandwiched jel...
# 5229   With what body must a pharmacy not be allowed ...
# 4012   The BankAmericard could be used across many me...
# 4784   In what year was Scott and Duncan's research p...
#
# [500 rows x 2 columns]

# %% [markdown]
# # Paraphrasing -> Translation

# %%
data = load_dataset("paws", "labeled_final", split="validation")
trans_df = data.to_pandas()
trans_df = trans_df.sample(1000)
trans_df
# Out:
# Downloading builder script:   0%|          | 0.00/8.43k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/7.52k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/9.34k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/49401 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/8000 [00:00<?, ? examples/s]
#         id                                          sentence1  \
# 7559  7560  The only other Jennings township is in Putnam ...
# 2840  2841  Pete Sampras won 6 -- 7 , 6 -- 4 , 7 -- 6 agai...
# 1096  1097  It is based in Luxembourg City , to the south ...
# 6607  6608  This festival also gives the participants an o...
# 5382  5383  The river Slatina is a tributary of the Bresni...
# ...    ...                                                ...
# 5946  5947  After the first round of the duel , Heine Totl...
# 5341  5342  In 2002 , the song was covered by British prod...
# 353    354  On 21 June 2016 , Cristina Ferrare replaced De...
# 1627  1628  The BBC College of Journalism was opened as an...
# 1856  1857  65 soldiers have been killed during the missio...
#
#                                               sentence2  label
# 7559  Statewide , the only other Jennings Township i...      1
# 2840  Tim Tim Henman won against Pete Sampras in the...      0
# 1096  It is based in Mondercange , south of Luxembou...      0
# 6607  This festival also gives participants the oppo...      0
# 5382  The Slatina River is a tributary of the Bresni...      1
# ...                                                 ...    ...
# 5946  After the first round of duels Heine Totland b...      1
# 5341  In 2002 , the song was released by British pro...      0
# 353   On June 21 , 2016 , Cristina Ferrare replaced ...      0
# 1627  In June 2005 , the BBC College of Journalism w...      1
# 1856  During the mission , 65 soldiers were killed :...      1
#
# [1000 rows x 4 columns]

# %%
trans_df = trans_df[trans_df["label"]==1]
trans_df = trans_df[["sentence1", "sentence2"]]
trans_df
# Out:
#                                               sentence1  \
# 7559  The only other Jennings township is in Putnam ...
# 5382  The river Slatina is a tributary of the Bresni...
# 4433  It is well known from the United States ( Main...
# 1222  Georgetown is also a source of drinking water ...
# 2227  In 1997 , she appeared as Sheila Dixon in `` C...
# ...                                                 ...
# 2756  de Ruiter , who was born in Leiden , played fo...
# 3354  The Azusa Campus at Azusa Pacific University i...
# 5946  After the first round of the duel , Heine Totl...
# 1627  The BBC College of Journalism was opened as an...
# 1856  65 soldiers have been killed during the missio...
#
#                                               sentence2
# 7559  Statewide , the only other Jennings Township i...
# 5382  The Slatina River is a tributary of the Bresni...
# 4433  It is known from the United States ( Maine , O...
# 1222  Georgetown is also a source of drinking water ...
# 2227  Hardwick appeared in `` Coronation Street '' i...
# ...                                                 ...
# 2756  de Ruiter was born in Leiden and played for RK...
# 3354  Azusa Pacific University 's Azusa campus is lo...
# 5946  After the first round of duels Heine Totland b...
# 1627  In June 2005 , the BBC College of Journalism w...
# 1856  During the mission , 65 soldiers were killed :...
#
# [416 rows x 2 columns]

# %%
trans_df["source"] = trans_df["sentence1"].apply(lambda x: "paraphrase: " + x)
trans_df["target"] = trans_df["sentence2"]
trans_df
# Out:
#                                               sentence1  \
# 7559  The only other Jennings township is in Putnam ...
# 5382  The river Slatina is a tributary of the Bresni...
# 4433  It is well known from the United States ( Main...
# 1222  Georgetown is also a source of drinking water ...
# 2227  In 1997 , she appeared as Sheila Dixon in `` C...
# ...                                                 ...
# 2756  de Ruiter , who was born in Leiden , played fo...
# 3354  The Azusa Campus at Azusa Pacific University i...
# 5946  After the first round of the duel , Heine Totl...
# 1627  The BBC College of Journalism was opened as an...
# 1856  65 soldiers have been killed during the missio...
#
#                                               sentence2  \
# 7559  Statewide , the only other Jennings Township i...
# 5382  The Slatina River is a tributary of the Bresni...
# 4433  It is known from the United States ( Maine , O...
# 1222  Georgetown is also a source of drinking water ...
# 2227  Hardwick appeared in `` Coronation Street '' i...
# ...                                                 ...
# 2756  de Ruiter was born in Leiden and played for RK...
# 3354  Azusa Pacific University 's Azusa campus is lo...
# 5946  After the first round of duels Heine Totland b...
# 1627  In June 2005 , the BBC College of Journalism w...
# 1856  During the mission , 65 soldiers were killed :...
#
#                                                  source  \
# 7559  paraphrase: The only other Jennings township i...
# 5382  paraphrase: The river Slatina is a tributary o...
# 4433  paraphrase: It is well known from the United S...
# 1222  paraphrase: Georgetown is also a source of dri...
# 2227  paraphrase: In 1997 , she appeared as Sheila D...
# ...                                                 ...
# 2756  paraphrase: de Ruiter , who was born in Leiden...
# 3354  paraphrase: The Azusa Campus at Azusa Pacific ...
# 5946  paraphrase: After the first round of the duel ...
# 1627  paraphrase: The BBC College of Journalism was ...
# 1856  paraphrase: 65 soldiers have been killed durin...
#
#                                                  target
# 7559  Statewide , the only other Jennings Township i...
# 5382  The Slatina River is a tributary of the Bresni...
# 4433  It is known from the United States ( Maine , O...
# 1222  Georgetown is also a source of drinking water ...
# 2227  Hardwick appeared in `` Coronation Street '' i...
# ...                                                 ...
# 2756  de Ruiter was born in Leiden and played for RK...
# 3354  Azusa Pacific University 's Azusa campus is lo...
# 5946  After the first round of duels Heine Totland b...
# 1627  In June 2005 , the BBC College of Journalism w...
# 1856  During the mission , 65 soldiers were killed :...
#
# [416 rows x 4 columns]

# %%
trans_df = trans_df[["source", "target"]]
trans_df
# Out:
#                                                  source  \
# 7559  paraphrase: The only other Jennings township i...
# 5382  paraphrase: The river Slatina is a tributary o...
# 4433  paraphrase: It is well known from the United S...
# 1222  paraphrase: Georgetown is also a source of dri...
# 2227  paraphrase: In 1997 , she appeared as Sheila D...
# ...                                                 ...
# 2756  paraphrase: de Ruiter , who was born in Leiden...
# 3354  paraphrase: The Azusa Campus at Azusa Pacific ...
# 5946  paraphrase: After the first round of the duel ...
# 1627  paraphrase: The BBC College of Journalism was ...
# 1856  paraphrase: 65 soldiers have been killed durin...
#
#                                                  target
# 7559  Statewide , the only other Jennings Township i...
# 5382  The Slatina River is a tributary of the Bresni...
# 4433  It is known from the United States ( Maine , O...
# 1222  Georgetown is also a source of drinking water ...
# 2227  Hardwick appeared in `` Coronation Street '' i...
# ...                                                 ...
# 2756  de Ruiter was born in Leiden and played for RK...
# 3354  Azusa Pacific University 's Azusa campus is lo...
# 5946  After the first round of duels Heine Totland b...
# 1627  In June 2005 , the BBC College of Journalism w...
# 1856  During the mission , 65 soldiers were killed :...
#
# [416 rows x 2 columns]

# %% [markdown]
# # Summarization

# %%
! pip install py7zr
# Out:
# Collecting py7zr
#   Downloading py7zr-0.20.6-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.7/66.7 kB 2.2 MB/s eta 0:00:00
# Collecting texttable (from py7zr)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting pycryptodomex>=3.6.6 (from py7zr)
#   Downloading pycryptodomex-3.19.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 17.1 MB/s eta 0:00:00
# Collecting pyzstd>=0.14.4 (from py7zr)
#   Downloading pyzstd-0.15.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (412 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 kB 27.9 MB/s eta 0:00:00
# Collecting pyppmd<1.1.0,>=0.18.1 (from py7zr)
#   Downloading pyppmd-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 17.7 MB/s eta 0:00:00
# Collecting pybcj>=0.6.0 (from py7zr)
#   Downloading pybcj-1.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.8/49.8 kB 6.8 MB/s eta 0:00:00
# Collecting multivolumefile>=0.2.3 (from py7zr)
#   Downloading multivolumefile-0.2.3-py3-none-any.whl (17 kB)
# Collecting brotli>=1.0.9 (from py7zr)
#   Downloading Brotli-1.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.4 MB/s eta 0:00:00
# Collecting inflate64>=0.3.1 (from py7zr)
#   Downloading inflate64-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from py7zr) (5.9.5)
# Installing collected packages: texttable, brotli, pyzstd, pyppmd, pycryptodomex, pybcj, multivolumefile, inflate64, py7zr
# Successfully installed brotli-1.1.0 inflate64-0.3.1 multivolumefile-0.2.3 py7zr-0.20.6 pybcj-1.0.1 pycryptodomex-3.19.0 pyppmd-1.0.0 pyzstd-0.15.9 texttable-1.7.0

# %%
data = load_dataset("samsum", split="test")
summ_df = data.to_pandas()
summ_df = summ_df[:500]
summ_df
# Out:
# Downloading builder script:   0%|          | 0.00/3.36k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.04k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.94M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/14732 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/819 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/818 [00:00<?, ? examples/s]
#            id                                           dialogue  \
# 0    13862856  Hannah: Hey, do you have Betty's number?\nAman...
# 1    13729565  Eric: MACHINE!\r\nRob: That's so gr8!\r\nEric:...
# 2    13680171  Lenny: Babe, can you help me with something?\r...
# 3    13729438  Will: hey babe, what do you want for dinner to...
# 4    13828600  Ollie: Hi , are you in Warsaw\r\nJane: yes, ju...
# ..        ...                                                ...
# 495  13828505  Amber: Hi Erin, guess what, John and Annie are...
# 496  13716957  Vicky: Is everyone still at town sq? I might h...
# 497  13829569  Kaylin: <file_gif> \r\nKaylin: that's what app...
# 498  13729275  Keira: How come it started with wildangel3 the...
# 499  13829296  Natacha: hi, i can come and pick you up at the...
#
#                                                summary
# 0    Hannah needs Betty's number but Amanda doesn't...
# 1    Eric and Rob are going to watch a stand-up on ...
# 2    Lenny can't decide which trousers to buy. Bob ...
# 3    Emma will be home soon and she will let Will k...
# 4    Jane is in Warsaw. Ollie and Jane has a party....
# ..                                                 ...
# 495  John and Annie are moving to London because he...
# 496           They are meeting at Fratellis, upstairs.
# 497             Kaylin has set her alarm for tomorrow.
# 498  Keira wonders why wildangel plays in the wrong...
# 499  Charles has just landed and he will be at RER ...
#
# [500 rows x 3 columns]

# %%
summ_df["source"] = summ_df["dialogue"].apply(lambda x: "conversation-summarization: " + x)
summ_df["target"] = summ_df["summary"]
summ_df = summ_df[["source", "target"]]
summ_df
# Out:
#                                                 source  \
# 0    conversation-summarization: Hannah: Hey, do yo...
# 1    conversation-summarization: Eric: MACHINE!\r\n...
# 2    conversation-summarization: Lenny: Babe, can y...
# 3    conversation-summarization: Will: hey babe, wh...
# 4    conversation-summarization: Ollie: Hi , are yo...
# ..                                                 ...
# 495  conversation-summarization: Amber: Hi Erin, gu...
# 496  conversation-summarization: Vicky: Is everyone...
# 497  conversation-summarization: Kaylin: <file_gif>...
# 498  conversation-summarization: Keira: How come it...
# 499  conversation-summarization: Natacha: hi, i can...
#
#                                                 target
# 0    Hannah needs Betty's number but Amanda doesn't...
# 1    Eric and Rob are going to watch a stand-up on ...
# 2    Lenny can't decide which trousers to buy. Bob ...
# 3    Emma will be home soon and she will let Will k...
# 4    Jane is in Warsaw. Ollie and Jane has a party....
# ..                                                 ...
# 495  John and Annie are moving to London because he...
# 496           They are meeting at Fratellis, upstairs.
# 497             Kaylin has set her alarm for tomorrow.
# 498  Keira wonders why wildangel plays in the wrong...
# 499  Charles has just landed and he will be at RER ...
#
# [500 rows x 2 columns]

# %% [markdown]
# # Text Generation

# %%
data = load_dataset("sadFaceEmoji/english-poems", split="train")
text_gen_df = data.to_pandas()
text_gen_df = text_gen_df.sample(500)
# Out:
# Downloading readme:   0%|          | 0.00/131 [00:00<?, ?B/s]
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/20.3M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
text_gen_df
# Out:
#           id                                               poem
# 57682  57682  he sighing paused\nlo then the serpent hissed\...
# 36650  36650  beneath my palm trees by the river side\ni sat...
# 52942  52942  my heart is wildly beating\ncome bridegroom co...
# 17258  17258  the true strains rise only from\nthe rich red ...
# 12957  12957  like the lizard in the furious noon\nthat drop...
# ...      ...                                                ...
# 51820  51820  but when he came to denver in that fall uv\nhi...
# 54647  54647  the skiff was like a crescent ghost of some mo...
# 7558    7558  and if so\nthe poetry of fall\nis the dog of m...
# 6641    6641  for breakfast a man must break an egg\nthen no...
# 73599  73599  youth large lusty loving youth full of grace f...
#
# [500 rows x 2 columns]

# %%
text_gen_df = text_gen_df.dropna()
text_gen_df
# Out:
#           id                                               poem
# 57682  57682  he sighing paused\nlo then the serpent hissed\...
# 36650  36650  beneath my palm trees by the river side\ni sat...
# 52942  52942  my heart is wildly beating\ncome bridegroom co...
# 17258  17258  the true strains rise only from\nthe rich red ...
# 12957  12957  like the lizard in the furious noon\nthat drop...
# ...      ...                                                ...
# 51820  51820  but when he came to denver in that fall uv\nhi...
# 54647  54647  the skiff was like a crescent ghost of some mo...
# 7558    7558  and if so\nthe poetry of fall\nis the dog of m...
# 6641    6641  for breakfast a man must break an egg\nthen no...
# 73599  73599  youth large lusty loving youth full of grace f...
#
# [500 rows x 2 columns]

# %%
a = text_gen_df.iloc[0]["poem"].split(" ")

# %%
" ".join(a)
# Out:
# 'he sighing paused\nlo then the serpent hissed\nin impotent rage depart\nand how depart'

# %%
import random

def poem_splitter(text):
    word_list = text.split(" ")

    if len(word_list) >=0:

        num_words = random.randint(0, len(word_list)//2)

        source = " ".join(word_list[:num_words])

        target = " ".join(word_list[num_words: ])

    else:

        source = "drop"

        target = "drop"

    return [source, target]

# %%
text_gen_df["source"] = text_gen_df["poem"].apply(lambda x: poem_splitter(x))
text_gen_df["target"] = text_gen_df["source"].apply(lambda x: x[1])
text_gen_df["source"] = text_gen_df["source"].apply(lambda x: "poem-completion: " + x[0])

# %%
text_gen_df
# Out:
#           id                                               poem  \
# 57682  57682  he sighing paused\nlo then the serpent hissed\...
# 36650  36650  beneath my palm trees by the river side\ni sat...
# 52942  52942  my heart is wildly beating\ncome bridegroom co...
# 17258  17258  the true strains rise only from\nthe rich red ...
# 12957  12957  like the lizard in the furious noon\nthat drop...
# ...      ...                                                ...
# 51820  51820  but when he came to denver in that fall uv\nhi...
# 54647  54647  the skiff was like a crescent ghost of some mo...
# 7558    7558  and if so\nthe poetry of fall\nis the dog of m...
# 6641    6641  for breakfast a man must break an egg\nthen no...
# 73599  73599  youth large lusty loving youth full of grace f...
#
#                                                   source  \
# 57682             poem-completion: he sighing paused\nlo
# 36650  poem-completion: beneath my palm trees by the ...
# 52942                                  poem-completion:
# 17258  poem-completion: the true strains rise only fr...
# 12957                   poem-completion: like the lizard
# ...                                                  ...
# 51820  poem-completion: but when he came to denver in...
# 54647     poem-completion: the skiff was like a crescent
# 7558   poem-completion: and if so\nthe poetry of fall...
# 6641   poem-completion: for breakfast a man must brea...
# 73599  poem-completion: youth large lusty loving yout...
#
#                                                   target
# 57682  then the serpent hissed\nin impotent rage depa...
# 36650  a weeping: in the whole world wide\nthere was ...
# 52942  my heart is wildly beating\ncome bridegroom co...
# 17258  and singers together or\napart beyond friendsh...
# 12957  in the furious noon\nthat drops his legs and c...
# ...                                                  ...
# 51820  spree\nthe very thought uv seein' dana worked ...
# 54647  ghost of some moon departed\nfrail white she r...
# 7558   untied\nat last from the rope\nof the world\nd...
# 6641   all the king's men can do very much about it\n...
# 73599  force fascination\ndo you know that old age ma...
#
# [500 rows x 4 columns]

# %%
text_gen_df = text_gen_df[["source", "target"]]

text_gen_df
# Out:
#                                                   source  \
# 57682             poem-completion: he sighing paused\nlo
# 36650  poem-completion: beneath my palm trees by the ...
# 52942                                  poem-completion:
# 17258  poem-completion: the true strains rise only fr...
# 12957                   poem-completion: like the lizard
# ...                                                  ...
# 51820  poem-completion: but when he came to denver in...
# 54647     poem-completion: the skiff was like a crescent
# 7558   poem-completion: and if so\nthe poetry of fall...
# 6641   poem-completion: for breakfast a man must brea...
# 73599  poem-completion: youth large lusty loving yout...
#
#                                                   target
# 57682  then the serpent hissed\nin impotent rage depa...
# 36650  a weeping: in the whole world wide\nthere was ...
# 52942  my heart is wildly beating\ncome bridegroom co...
# 17258  and singers together or\napart beyond friendsh...
# 12957  in the furious noon\nthat drops his legs and c...
# ...                                                  ...
# 51820  spree\nthe very thought uv seein' dana worked ...
# 54647  ghost of some moon departed\nfrail white she r...
# 7558   untied\nat last from the rope\nof the world\nd...
# 6641   all the king's men can do very much about it\n...
# 73599  force fascination\ndo you know that old age ma...
#
# [500 rows x 2 columns]

# %% [markdown]
# # NLI

# %%
data = load_dataset("paws", "labeled_final", split="test")
nli_df = data.to_pandas()
nli_df = nli_df.sample(500)

nli_df
# Out:
#         id                                          sentence1  \
# 4331  4332  Liv meets Tyler to ask him to leave her brothe...
# 4014  4015  At first he recruited singer Ali Azmat of the ...
# 3889  3890  They do not follow the pattern of caldera grow...
# 2857  2858  Both electromagnetic brakes and eddy current b...
# 223    224  He returned to South Africa and went to the Ki...
# ...    ...                                                ...
# 1128  1129  Misc Music is a compilation album by Shifty Tr...
# 126    127  Oecomys rutilus , also known as the red arbore...
# 6360  6361  Grace Grace Elliott also appears as a major ch...
# 6587  6588  Meanwhile , Ben begins to connect with Norman ...
# 5250  5251  After goldust became Meanie , Meanie Goldust '...
#
#                                               sentence2  label
# 4331  Tyler meets Liv to ask him to leave her brothe...      0
# 4014  First , he recruited singer Nusrat Hussain fro...      0
# 3889  They do not follow the pattern of caldera - gr...      1
# 2857  Both electromagnetic brakes and eddy current b...      0
# 223   He returned to South Africa and went to King E...      1
# ...                                                 ...    ...
# 1128  Music is a compilation album by Unbelievable T...      0
# 126   Oecomys rutilus , also known as the reddish oe...      0
# 6360  Hallie Rubenhold also appears as a major chara...      0
# 6587  Meanwhile , Ben starts to connect with Norman ...      1
# 5250  After Goldust became Meanie at , Meanie defeat...      0
#
# [500 rows x 4 columns]

# %%
nli_df["source"] = nli_df[["sentence1", "sentence2"]].apply(lambda x: "nli-hypothesis-check: sentence1: " + x["sentence1"] + " sentence2: " + x["sentence2"], axis=1)
nli_df
# Out:
#         id                                          sentence1  \
# 4331  4332  Liv meets Tyler to ask him to leave her brothe...
# 4014  4015  At first he recruited singer Ali Azmat of the ...
# 3889  3890  They do not follow the pattern of caldera grow...
# 2857  2858  Both electromagnetic brakes and eddy current b...
# 223    224  He returned to South Africa and went to the Ki...
# ...    ...                                                ...
# 1128  1129  Misc Music is a compilation album by Shifty Tr...
# 126    127  Oecomys rutilus , also known as the red arbore...
# 6360  6361  Grace Grace Elliott also appears as a major ch...
# 6587  6588  Meanwhile , Ben begins to connect with Norman ...
# 5250  5251  After goldust became Meanie , Meanie Goldust '...
#
#                                               sentence2  label  \
# 4331  Tyler meets Liv to ask him to leave her brothe...      0
# 4014  First , he recruited singer Nusrat Hussain fro...      0
# 3889  They do not follow the pattern of caldera - gr...      1
# 2857  Both electromagnetic brakes and eddy current b...      0
# 223   He returned to South Africa and went to King E...      1
# ...                                                 ...    ...
# 1128  Music is a compilation album by Unbelievable T...      0
# 126   Oecomys rutilus , also known as the reddish oe...      0
# 6360  Hallie Rubenhold also appears as a major chara...      0
# 6587  Meanwhile , Ben starts to connect with Norman ...      1
# 5250  After Goldust became Meanie at , Meanie defeat...      0
#
#                                                  source
# 4331  nli-hypothesis-check: sentence1: Liv meets Tyl...
# 4014  nli-hypothesis-check: sentence1: At first he r...
# 3889  nli-hypothesis-check: sentence1: They do not f...
# 2857  nli-hypothesis-check: sentence1: Both electrom...
# 223   nli-hypothesis-check: sentence1: He returned t...
# ...                                                 ...
# 1128  nli-hypothesis-check: sentence1: Misc Music is...
# 126   nli-hypothesis-check: sentence1: Oecomys rutil...
# 6360  nli-hypothesis-check: sentence1: Grace Grace E...
# 6587  nli-hypothesis-check: sentence1: Meanwhile , B...
# 5250  nli-hypothesis-check: sentence1: After goldust...
#
# [500 rows x 5 columns]

# %%
hypo_dict = {
    0: "contradiction",
    1: "entailment"
}

nli_df["target"] = nli_df["label"].apply(lambda x: hypo_dict[x])
nli_df = nli_df[["source", "target"]]
nli_df
# Out:
#                                                  source         target
# 4331  nli-hypothesis-check: sentence1: Liv meets Tyl...  contradiction
# 4014  nli-hypothesis-check: sentence1: At first he r...  contradiction
# 3889  nli-hypothesis-check: sentence1: They do not f...     entailment
# 2857  nli-hypothesis-check: sentence1: Both electrom...  contradiction
# 223   nli-hypothesis-check: sentence1: He returned t...     entailment
# ...                                                 ...            ...
# 1128  nli-hypothesis-check: sentence1: Misc Music is...  contradiction
# 126   nli-hypothesis-check: sentence1: Oecomys rutil...  contradiction
# 6360  nli-hypothesis-check: sentence1: Grace Grace E...  contradiction
# 6587  nli-hypothesis-check: sentence1: Meanwhile , B...     entailment
# 5250  nli-hypothesis-check: sentence1: After goldust...  contradiction
#
# [500 rows x 2 columns]

# %% [markdown]
# # Final Data

# %%
list_of_dfs = [text_classification_df, qgen_df, qa_df, nli_df, text_gen_df, summ_df, trans_df]

final_df = pd.concat(list_of_dfs, axis=0)
final_df
# Out:
#                                                  source  \
# 1488  text-classification-emotion: i managed however...
# 726   text-classification-emotion: i lift different ...
# 325   text-classification-emotion: i bought it at ur...
# 1961  text-classification-emotion: i remember wantin...
# 998   text-classification-emotion: i feel like he mo...
# ...                                                 ...
# 2756  paraphrase: de Ruiter , who was born in Leiden...
# 3354  paraphrase: The Azusa Campus at Azusa Pacific ...
# 5946  paraphrase: After the first round of the duel ...
# 1627  paraphrase: The BBC College of Journalism was ...
# 1856  paraphrase: 65 soldiers have been killed durin...
#
#                                                  target
# 1488                                               love
# 726                                                fear
# 325                                             sadness
# 1961                                               love
# 998                                                 joy
# ...                                                 ...
# 2756  de Ruiter was born in Leiden and played for RK...
# 3354  Azusa Pacific University 's Azusa campus is lo...
# 5946  After the first round of duels Heine Totland b...
# 1627  In June 2005 , the BBC College of Journalism w...
# 1856  During the mission , 65 soldiers were killed :...
#
# [3423 rows x 2 columns]

# %% [markdown]
# # Finetune

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from peft import LoraConfig, get_peft_model
from transformers import Seq2SeqTrainer, Seq2SeqTrainingArguments, DataCollatorForSeq2Seq
from sklearn.model_selection import train_test_split

# %%
train_df, test_df = train_test_split(final_df, test_size=0.1, random_state=0, shuffle=True)
train_data = Dataset.from_pandas(train_df)
test_data = Dataset.from_pandas(test_df)

# %%
model_id="google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]

# %%
def preprocess_function(sample,padding="max_length"):
    model_inputs = tokenizer(sample["source"], max_length=256, padding=padding, truncation=True)
    labels = tokenizer(sample["target"], max_length=128, padding=padding, truncation=True)
    if padding == "max_length":
        labels["input_ids"] = [
            [(l if l != tokenizer.pad_token_id else -100) for l in label] for label in labels["input_ids"]
        ]
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
train_tokenized_dataset = train_data.map(preprocess_function, batched=True, remove_columns=train_data.column_names)
test_tokenized_dataset = test_data.map(preprocess_function, batched=True, remove_columns=test_data.column_names)
print(f"Keys of tokenized dataset: {list(train_tokenized_dataset.features)}")
# Out:
# Map:   0%|          | 0/3080 [00:00<?, ? examples/s]
# Map:   0%|          | 0/343 [00:00<?, ? examples/s]
# Keys of tokenized dataset: ['input_ids', 'attention_mask', 'labels']

# %%
lora_config = LoraConfig(
 r=8,
 lora_alpha=16,
 lora_dropout=0.1,
 bias="none",
 task_type="SEQ_2_SEQ_LM",
 target_modules=["q", "v"]
)

# %%
model
# Out:
# T5ForConditionalGeneration(
#   (shared): Embedding(32128, 1024)
#   (encoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (decoder): T5Stack(
#     (embed_tokens): Embedding(32128, 1024)
#     (block): ModuleList(
#       (0): T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#               (relative_attention_bias): Embedding(32, 16)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (1-23): 23 x T5Block(
#         (layer): ModuleList(
#           (0): T5LayerSelfAttention(
#             (SelfAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (1): T5LayerCrossAttention(
#             (EncDecAttention): T5Attention(
#               (q): Linear(in_features=1024, out_features=1024, bias=False)
#               (k): Linear(in_features=1024, out_features=1024, bias=False)
#               (v): Linear(in_features=1024, out_features=1024, bias=False)
#               (o): Linear(in_features=1024, out_features=1024, bias=False)
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (2): T5LayerFF(
#             (DenseReluDense): T5DenseGatedActDense(
#               (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#               (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#               (wo): Linear(in_features=2816, out_features=1024, bias=False)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (act): NewGELUActivation()
#             )
#             (layer_norm): T5LayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (final_layer_norm): T5LayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
# )

# %%
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 2,359,296 || all params: 785,509,376 || trainable%: 0.30035236651331837

# %%
model
# Out:
# PeftModelForSeq2SeqLM(
#   (base_model): LoraModel(
#     (model): T5ForConditionalGeneration(
#       (shared): Embedding(32128, 1024)
#       (encoder): T5Stack(
#         (embed_tokens): Embedding(32128, 1024)
#         (block): ModuleList(
#           (0): T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                   (relative_attention_bias): Embedding(32, 16)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wo): Linear(in_features=2816, out_features=1024, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (1-23): 23 x T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wo): Linear(in_features=2816, out_features=1024, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (final_layer_norm): T5LayerNorm()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (decoder): T5Stack(
#         (embed_tokens): Embedding(32128, 1024)
#         (block): ModuleList(
#           (0): T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                   (relative_attention_bias): Embedding(32, 16)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerCrossAttention(
#                 (EncDecAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (2): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wo): Linear(in_features=2816, out_features=1024, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#           (1-23): 23 x T5Block(
#             (layer): ModuleList(
#               (0): T5LayerSelfAttention(
#                 (SelfAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (1): T5LayerCrossAttention(
#                 (EncDecAttention): T5Attention(
#                   (q): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (k): Linear(in_features=1024, out_features=1024, bias=False)
#                   (v): Linear(
#                     in_features=1024, out_features=1024, bias=False
#                     (lora_dropout): ModuleDict(
#                       (default): Dropout(p=0.1, inplace=False)
#                     )
#                     (lora_A): ModuleDict(
#                       (default): Linear(in_features=1024, out_features=8, bias=False)
#                     )
#                     (lora_B): ModuleDict(
#                       (default): Linear(in_features=8, out_features=1024, bias=False)
#                     )
#                     (lora_embedding_A): ParameterDict()
#                     (lora_embedding_B): ParameterDict()
#                   )
#                   (o): Linear(in_features=1024, out_features=1024, bias=False)
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#               (2): T5LayerFF(
#                 (DenseReluDense): T5DenseGatedActDense(
#                   (wi_0): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wi_1): Linear(in_features=1024, out_features=2816, bias=False)
#                   (wo): Linear(in_features=2816, out_features=1024, bias=False)
#                   (dropout): Dropout(p=0.1, inplace=False)
#                   (act): NewGELUActivation()
#                 )
#                 (layer_norm): T5LayerNorm()
#                 (dropout): Dropout(p=0.1, inplace=False)
#               )
#             )
#           )
#         )
#         (final_layer_norm): T5LayerNorm()
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (lm_head): Linear(in_features=1024, out_features=32128, bias=False)
#     )
#   )
# )

# %%
label_pad_token_id = -100
data_collator = DataCollatorForSeq2Seq(
    tokenizer,
    model=model,
    label_pad_token_id=label_pad_token_id,
    pad_to_multiple_of=8
)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
output_dir="flant5-large-aio"
training_args = Seq2SeqTrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=6,
    learning_rate=2e-4,
    num_train_epochs=1,
    logging_dir=f"{output_dir}/logs",
    logging_strategy="epoch",
    save_strategy="epoch",
    report_to="tensorboard",
    push_to_hub = True
)

# %%
model.config.use_cache = False

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_tokenized_dataset
)

# %%
trainer.train()
# Out:
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='514' max='514' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [514/514 11:29, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>514</td>
#       <td>2.141500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=514, training_loss=2.141537202471425, metrics={'train_runtime': 695.2118, 'train_samples_per_second': 4.43, 'train_steps_per_second': 0.739, 'total_flos': 3560504190566400.0, 'train_loss': 2.141537202471425, 'epoch': 1.0})

# %%
peft_save_model_id="flant5-large-aio"
trainer.model.save_pretrained(peft_save_model_id, push_to_hub=True)
tokenizer.save_pretrained(peft_save_model_id, push_to_hub=True)
trainer.model.base_model.save_pretrained(peft_save_model_id, push_to_hub=True)
# Out:
# pytorch_model.bin:   0%|          | 0.00/3.14G [00:00<?, ?B/s]
